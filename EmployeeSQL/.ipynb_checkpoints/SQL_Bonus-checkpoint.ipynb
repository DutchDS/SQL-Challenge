# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:Lim8burg!@localhost:5432/GlobalFirePower_db')
connection = engine.connect()

# %%
import pandas as pd

# %%
df_new = pd.read_sql('firepower', engine)

# %%
df_new.head()
# Out:
#          country iso3  rank  totalpopulation  manpoweravailable  \
# 0  United States  USA   1.0        323995528        145215000.0
# 1         Russia  RUS   2.0        142355415         70000000.0
# 2          China  CHN   3.0       1373541278        750000000.0
# 3          India  IND   4.0       1266883598        616000000.0
# 4         France  FRA   5.0         66836154         30000000.0
#
#    totalmilitarypersonnel  activepersonnel  reservepersonnel  \
# 0                 2363675        1373650.0          990025.0
# 1                 3371027         798527.0         2572500.0
# 2                 3712500        2260000.0         1452500.0
# 3                 4207250        1362500.0         2844750.0
# 4                  387635         204000.0          183635.0
#
#    totalaircraftstrength  fighteraircraft  attackaircraft  \
# 0                  13763           2297.0          2785.0
# 1                   3795            807.0          1438.0
# ...
